# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("data", "train.csv"))
df_train = df[['Type', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
       'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
       'Sterilized', 'Health', 'Quantity', 'AdoptionSpeed']]
df_train.head()
# Out:
#    Type  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  MaturitySize  \
# 0     2    3     299       0       1       1       7       0             1
# 1     2    1     265       0       1       1       2       0             2
# 2     1    1     307       0       1       2       7       0             2
# 3     1    4     307       0       2       1       2       0             2
# 4     1    1     307       0       1       1       0       0             2
#
#    FurLength  Vaccinated  Dewormed  Sterilized  Health  Quantity  \
# 0          1           2         2           2       1         1
# 1          2           3         3           3       1         1
# 2          2           1         1           2       1         1
# 3          1           1         1           2       1         1
# 4          1           2         2           2       1         1
#
#    AdoptionSpeed
# 0              2
# 1              0
# 2              3
# 3              2
# 4              2

# %%
df_train.isnull().sum()
# Out:
# Type             0
# Age              0
# Breed1           0
# Breed2           0
# Gender           0
# Color1           0
# Color2           0
# Color3           0
# MaturitySize     0
# FurLength        0
# Vaccinated       0
# Dewormed         0
# Sterilized       0
# Health           0
# Quantity         0
# AdoptionSpeed    0
# dtype: int64

# %%
target = df_train["AdoptionSpeed"]
target_names = ["0", "1", "2", "3", "4"]

# %%
data = df_train.drop("AdoptionSpeed", axis=1)
feature_names = data.columns
data.head()
# Out:
#    Type  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  MaturitySize  \
# 0     2    3     299       0       1       1       7       0             1
# 1     2    1     265       0       1       1       2       0             2
# 2     1    1     307       0       1       2       7       0             2
# 3     1    4     307       0       2       1       2       0             2
# 4     1    1     307       0       1       1       0       0             2
#
#    FurLength  Vaccinated  Dewormed  Sterilized  Health  Quantity
# 0          1           2         2           2       1         1
# 1          2           3         3           3       1         1
# 2          2           1         1           2       1         1
# 3          1           1         1           2       1         1
# 4          1           2         2           2       1         1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
model = tree.DecisionTreeClassifier()
model = model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.3107495332088557

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=500)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.36596425713523606

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.18850671752958456, 'Age'),
#  (0.10924711134419292, 'Color1'),
#  (0.10911454507148116, 'Color2'),
#  (0.10337279816220164, 'Breed1'),
#  (0.07395220062389517, 'Breed2'),
#  (0.058337898461432065, 'Quantity'),
#  (0.05474118148198609, 'Gender'),
#  (0.05446741847006755, 'FurLength'),
#  (0.05344648624927267, 'MaturitySize'),
#  (0.053156090389934386, 'Color3'),
#  (0.04104678434060599, 'Dewormed'),
#  (0.03814295728458204, 'Sterilized'),
#  (0.037877529616084885, 'Vaccinated'),
#  (0.01402156401493949, 'Health'),
#  (0.01056871695973937, 'Type')]
