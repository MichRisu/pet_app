# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(os.path.join("data", "train.csv"))
df_train = df[['Type', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
       'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
       'Sterilized', 'Health', 'Quantity', 'AdoptionSpeed']]
df_train.head()
# Out:
#    Type  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  MaturitySize  \
# 0     2    3     299       0       1       1       7       0             1
# 1     2    1     265       0       1       1       2       0             2
# 2     1    1     307       0       1       2       7       0             2
# 3     1    4     307       0       2       1       2       0             2
# 4     1    1     307       0       1       1       0       0             2
#
#    FurLength  Vaccinated  Dewormed  Sterilized  Health  Quantity  \
# 0          1           2         2           2       1         1
# 1          2           3         3           3       1         1
# 2          2           1         1           2       1         1
# 3          1           1         1           2       1         1
# 4          1           2         2           2       1         1
#
#    AdoptionSpeed
# 0              2
# 1              0
# 2              3
# 3              2
# 4              2

# %%
y = df_train["AdoptionSpeed"]
target_names = ["0", "1", "2", "3", "4"]

# %%
X = df_train.drop("AdoptionSpeed", axis=1)
feature_names = X.columns
X.head()
# Out:
#    Type  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  MaturitySize  \
# 0     2    3     299       0       1       1       7       0             1
# 1     2    1     265       0       1       1       2       0             2
# 2     1    1     307       0       1       2       7       0             2
# 3     1    4     307       0       2       1       2       0             2
# 4     1    1     307       0       1       1       0       0             2
#
#    FurLength  Vaccinated  Dewormed  Sterilized  Health  Quantity
# 0          1           2         2           2       1         1
# 1          2           3         3           3       1         1
# 2          2           1         1           2       1         1
# 3          1           1         1           2       1         1
# 4          1           2         2           2       1         1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-dd07e0e88134> in <module>
#       1 from sklearn.svm import SVC
#       2 model = SVC(kernel='precomputed')
# ----> 3 model.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     163             raise ValueError("Precomputed matrix must be a square matrix."
#     164                              " Input is a {}x{} matrix."
# --> 165                              .format(X.shape[0], X.shape[1]))
#     166
#     167         if sample_weight.shape[0] > 0 and sample_weight.shape[0] != X.shape[0]:
#
# ValueError: Precomputed matrix must be a square matrix. Input is a 11244x15 matrix.

# %%
print("Test Acc: %.3f" % model.score(X_test, y_test))
# Out:
# Test Acc: 0.205

# %%
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       114
#            1       0.44      0.01      0.01       773
#            2       0.28      0.60      0.38       994
#            3       0.00      0.00      0.00       813
#            4       0.38      0.58      0.46      1055
#
#     accuracy                           0.32      3749
#    macro avg       0.22      0.24      0.17      3749
# weighted avg       0.27      0.32      0.23      3749
# /Users/MichMac/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
